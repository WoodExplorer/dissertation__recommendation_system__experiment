# %%
import gensim
import logging
import sqlite3

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#model_path = '/home/wsyj/dissertation__recommendation_system__experiment_2/dissertation__recommendation_system__experiment/main_modelnum_features=400_min_count=2_window=1.model'
model_path = 'main_modelnum_features=400_min_count=2_window=1.model'
model = gensim.models.Word2Vec.load(model_path)
# Out:
# 2017-02-19 10:07:15,078 : INFO : loading Word2Vec object from main_modelnum_features=400_min_count=2_window=1.model
# 2017-02-19 10:07:15,091 : INFO : loading wv recursively from main_modelnum_features=400_min_count=2_window=1.model.wv.* with mmap=None
# 2017-02-19 10:07:15,092 : INFO : setting ignored attribute syn0norm to None
# 2017-02-19 10:07:15,092 : INFO : setting ignored attribute cum_table to None
# 2017-02-19 10:07:15,093 : INFO : loaded main_modelnum_features=400_min_count=2_window=1.model

# %%
dir(model)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__ignoreds',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__numpys',
#  '__recursive_saveloads',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__scipys',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_do_train_job',
#  '_load_specials',
#  '_minimize_model',
#  '_raw_word_count',
#  '_save_specials',
#  '_smart_save',
#  'accuracy',
#  'alpha',
#  'batch_words',
#  'build_vocab',
#  'cbow_mean',
#  'clear_sims',
#  'corpus_count',
#  'create_binary_tree',
#  'cum_table',
#  'delete_temporary_training_data',
#  'disable_keyed_vectors_warnings',
#  'doesnt_match',
#  'enable_keyed_vectors_warnings',
#  'estimate_memory',
#  'evaluate_word_pairs',
#  'finalize_vocab',
#  'hashfxn',
#  'hs',
#  'index2word',
#  'init_sims',
# ...

# %%
model.vocab
# Out:
# 2017-02-19 10:07:24,890 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# {'2031': <gensim.models.word2vec.Vocab at 0xaa190d0c>,
#  '1869': <gensim.models.word2vec.Vocab at 0xaa19006c>,
#  '643': <gensim.models.word2vec.Vocab at 0xaa190acc>,
#  '344': <gensim.models.word2vec.Vocab at 0xaa21d42c>,
#  '345': <gensim.models.word2vec.Vocab at 0xaa21d44c>,
#  '346': <gensim.models.word2vec.Vocab at 0xaa21d46c>,
#  '347': <gensim.models.word2vec.Vocab at 0xaa21d48c>,
#  '340': <gensim.models.word2vec.Vocab at 0xaa21d4ac>,
#  '341': <gensim.models.word2vec.Vocab at 0xaa21d4cc>,
#  '342': <gensim.models.word2vec.Vocab at 0xaa21d4ec>,
#  '343': <gensim.models.word2vec.Vocab at 0xaa21d50c>,
#  '348': <gensim.models.word2vec.Vocab at 0xaa21d52c>,
#  '349': <gensim.models.word2vec.Vocab at 0xaa21d54c>,
#  '2318': <gensim.models.word2vec.Vocab at 0xaa21d5ec>,
#  '2316': <gensim.models.word2vec.Vocab at 0xaa21d62c>,
# ...

# %%
#   -1.82822179e-02   1.55187175e-02  -7.34281242e-02  -9.69148502e-02
#   -5.09209335e-02  -3.65169942e-02  -1.26820505e-02  -3.58918719e-02
#   -5.72726317e-02  -2.16217432e-02   1.60165075e-02  -4.46259342e-02
#    1.64738707e-02  -8.47870298e-03  -1.64557770e-02  -1.56951894e-03
#    4.07068618e-02   5.71773723e-02   3.53537649e-02  -7.45123136e-04
#   -3.55745517e-02  -3.56679608e-04  -1.38474088e-02  -6.83311820e-02
#   -9.32695251e-03   3.63950320e-02  -2.10441500e-02   2.27138288e-02
#    7.11990148e-02   1.04804300e-01   3.28180194e-02  -8.77623707e-02
# ...

# %%
#model_path = '/home/wsyj/dissertation__recommendation_system__experiment_2/dissertation__recommendation_system__experiment/main_modelnum_features=400_min_count=2_window=1.model'
model_path = 'main_modelnum_features=480_min_count=1_window=4_iter=35.model'
model = gensim.models.Word2Vec.load(model_path)
# Out:
# 2017-02-19 15:16:06,857 : INFO : loading Word2Vec object from main_modelnum_features=480_min_count=1_window=4_iter=35.model
# 2017-02-19 15:16:06,873 : INFO : loading wv recursively from main_modelnum_features=480_min_count=1_window=4_iter=35.model.wv.* with mmap=None
# 2017-02-19 15:16:06,874 : INFO : setting ignored attribute syn0norm to None
# 2017-02-19 15:16:06,874 : INFO : setting ignored attribute cum_table to None
# 2017-02-19 15:16:06,875 : INFO : loaded main_modelnum_features=480_min_count=1_window=4_iter=35.model

# %%
model.vocab
# Out:
# 2017-02-19 15:16:08,906 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# {'2031': <gensim.models.word2vec.Vocab at 0xaa06ae0c>,
#  '1869': <gensim.models.word2vec.Vocab at 0xaa06a10c>,
#  '1868': <gensim.models.word2vec.Vocab at 0xaa06a14c>,
#  '643': <gensim.models.word2vec.Vocab at 0xaa06abcc>,
#  '344': <gensim.models.word2vec.Vocab at 0xa95bbdac>,
#  '345': <gensim.models.word2vec.Vocab at 0xa95bbdcc>,
#  '346': <gensim.models.word2vec.Vocab at 0xa95bbdec>,
#  '347': <gensim.models.word2vec.Vocab at 0xa95bbe0c>,
#  '340': <gensim.models.word2vec.Vocab at 0xa95bbe2c>,
#  '341': <gensim.models.word2vec.Vocab at 0xa95bbe4c>,
#  '342': <gensim.models.word2vec.Vocab at 0xa95bbe6c>,
#  '343': <gensim.models.word2vec.Vocab at 0xa95bbe8c>,
#  '348': <gensim.models.word2vec.Vocab at 0xa95bbeec>,
#  '349': <gensim.models.word2vec.Vocab at 0xa95bbf0c>,
#  '2318': <gensim.models.word2vec.Vocab at 0xa95bbfac>,
# ...

# %%
r = model.most_similar('341', topn=10000)
print r[:100]
# Out:
# 2017-02-19 15:16:17,762 : INFO : precomputing L2-norms of word weight vectors
# ...
