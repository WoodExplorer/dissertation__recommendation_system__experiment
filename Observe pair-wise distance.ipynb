# %%
import gensim

# %%
model_path = 'main_modelnum_features=100_min_count=1_window=1_iter=30.model'

model = gensim.models.Word2Vec.load(model_path)

# %%
model.vocab
# Out:
# {'2031': <gensim.models.word2vec.Vocab at 0xa9c7d16c>,
#  '1869': <gensim.models.word2vec.Vocab at 0xa9c7744c>,
#  '1868': <gensim.models.word2vec.Vocab at 0xa9c7748c>,
#  '643': <gensim.models.word2vec.Vocab at 0xa9c9d94c>,
#  '344': <gensim.models.word2vec.Vocab at 0xaa22744c>,
#  '345': <gensim.models.word2vec.Vocab at 0xaa22746c>,
#  '346': <gensim.models.word2vec.Vocab at 0xaa22748c>,
#  '347': <gensim.models.word2vec.Vocab at 0xaa2274ac>,
#  '340': <gensim.models.word2vec.Vocab at 0xaa2274cc>,
#  '341': <gensim.models.word2vec.Vocab at 0xaa2274ec>,
#  '342': <gensim.models.word2vec.Vocab at 0xaa22750c>,
#  '343': <gensim.models.word2vec.Vocab at 0xaa22752c>,
#  '348': <gensim.models.word2vec.Vocab at 0xaa22754c>,
#  '349': <gensim.models.word2vec.Vocab at 0xaa22756c>,
#  '2318': <gensim.models.word2vec.Vocab at 0xaa22760c>,
#  '2316': <gensim.models.word2vec.Vocab at 0xaa22764c>,
#  '2317': <gensim.models.word2vec.Vocab at 0xaa22768c>,
# ...

# %%
model.most_similar('2031', topn=500)
# Out:
# [('2032', 0.9334377646446228),
#  ('3913', 0.925700306892395),
#  ('96', 0.8876870274543762),
#  ('3912', 0.8868482708930969),
#  ('3915', 0.8824079632759094),
#  ('3771', 0.8799571990966797),
#  ('97', 0.878061056137085),
#  ('3914', 0.8513879776000977),
#  ('2033', 0.8503250479698181),
#  ('98', 0.8446516394615173),
#  ('2036', 0.8417719602584839),
#  ('3775', 0.8413050174713135),
#  ('3772', 0.839969277381897),
#  ('558', 0.8355758786201477),
#  ('99', 0.8343368172645569),
#  ('3770', 0.8276649713516235),
#  ('1087', 0.827531635761261),
#  ('554', 0.8259638547897339),
#  ('2035', 0.8239185810089111),
#  ('556', 0.8239185214042664),
#  ('2970', 0.8191434144973755),
#  ('93', 0.8159270882606506),
#  ('3843', 0.8123072981834412),
#  ('90', 0.7704504132270813),
#  ('2104', 0.7664232850074768),
#  ('3773', 0.7635186910629272),
#  ('3917', 0.7548551559448242),
#  ('1232', 0.7544353008270264),
#  ('92', 0.7472934722900391),
#  ('2034', 0.7455348372459412),
# ...
