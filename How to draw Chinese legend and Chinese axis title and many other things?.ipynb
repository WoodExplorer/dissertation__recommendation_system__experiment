# %%
"""This notebook
（1） demonstrates how to draw Chinese legend in 2 ways, the plt way and the pandas way.
（2） demonstrates how to apply different markers to points on different lines.

Many thanks to 
http://stackoverflow.com/questions/23197124/display-non-ascii-japanese-characters-in-pandas-plot-legend
and many other websites and their content.
!
"""
# Out:
# 'This notebook demonstrates how to draw Chinese legend in 2 ways, the plt way and the pandas way.\n\nMany thanks to \nhttp://stackoverflow.com/questions/23197124/display-non-ascii-japanese-characters-in-pandas-plot-legend\n!\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# %%
prop = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')
plt.plot( np.arange(10), np.arange(10), label=u'日本', marker='o', markersize=5, color='black')
plt.plot( np.arange(10) * -1, np.arange(10), label=u'日本2', marker='^', markersize=5, color='black')
plt.legend( prop=prop )
plt.show()

# %%
df = pd.DataFrame( data=[[1,2], [10, 20]], columns=[u'é',u'日本'] )

ax = df.plot()
legend = ax.legend()
font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

for text in legend.texts:
    text.set_font_properties(font)
    
plt.xlabel(u'中文', fontproperties=font)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

df = pd.DataFrame( data=[[1,2], [10, 20]], columns=[u'é',u'日本'] )

ax = df.plot()
legend = ax.legend()
font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

for text in legend.texts:
    text.set_font_properties(font)

ax.set_xlabel(u'中')

for label in ax.get_xticklabels() :
    label.set_fontproperties(font)
    
plt.xlabel(u'中文', fontproperties=font)
#label = ax.get_xlabel()
#print label
#label = ax.get_label()
#print label
#print label.set_font_properties(font)
#
plt.show()

# %%
# what will happen if you execute df.plot() multiple times?

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

df = pd.DataFrame( data=[1,2], columns=[u'é'] )



ax = df.plot()


df = pd.DataFrame( data=[10, 20], columns=[u'日本'] )

ax = df.plot()

legend = ax.legend()
font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

for text in legend.texts:
    text.set_font_properties(font)

ax.set_xlabel(u'中')

for label in ax.get_xticklabels() :
    label.set_fontproperties(font)
    
plt.xlabel(u'中文', fontproperties=font)
#label = ax.get_xlabel()
#print label
#label = ax.get_label()
#print label
#print label.set_font_properties(font)
#
plt.show()

# %%
# With help of subplot, we can apply different markers to points on different lines.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

fig1 = plt.figure()

df = pd.DataFrame( data=[1,2], columns=[u'é'] ) # It seems to me that when using underneath pyplot directly, the columns here will not translate to legend.

ax1 = fig1.add_subplot(111)
ax1.plot(df, label=u'é', marker='o')

df = pd.DataFrame( data=[10, 20], columns=[u'日本'] )

ax2 = fig1.add_subplot(111)
ax2.plot(df, label=u'日本', marker='*')


legend = plt.legend()
font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

for text in legend.texts:
    text.set_font_properties(font)

#plt.set_xlabel(u'中')
#
#for label in ax.get_xticklabels() :
#    label.set_fontproperties(font)
    
plt.xlabel(u'中文', fontproperties=font)

plt.show()

# %%
plt.legend
# Out:
# <function matplotlib.pyplot.legend>

# %%
df = pd.DataFrame( data=[[1,2], [10, 20]], index=[10, 20], columns=[u'é',u'日本'] )

ax = df.plot()
legend = ax.legend()
font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

for text in legend.texts:
    text.set_font_properties(font)
    
plt.xlabel(u'中文', fontproperties=font)
plt.show()

# %%
dir(ax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getstate__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_axes',
#  u'_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_cachedRenderer',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_current_image',
#  '_cursorProps',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_legend_handles',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
#  '_gid',
#  '_gridOn',
#  '_hold',
#  '_init_axis',
#  '_label',
#  '_left_title',
#  '_make_twin_axes',
# ...

# %%
ax.hitlist
# Out:
# <bound method AxesSubplot.hitlist of <matplotlib.axes._subplots.AxesSubplot object at 0xa88525ec>>

# %%
hist, bins = np.histogram(range(5), bins = 5)

# %%
bins
# Out:
# array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ])

# %%
hist
# Out:
# array([1, 1, 1, 1, 1])

# %%
"""Take away:

hist optional parameters: hatch, color and edgecolor
"""

font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')

#freq_list = [x[1] for x in movie_freq]
freq_list = [1, 2, 3, 4, 5]
df = pd.DataFrame(data=freq_list)

ax, = df.hist(bins=30, hatch='/', color='white', edgecolor='black')
ax = ax[0]
#legend = ax.legend()
#font = font_manager.FontProperties(fname='/home/wsyj/Downloads/simsun.ttc')
#
#for text in legend.texts:
#    text.set_font_properties(font)
#    

for i, label in enumerate(range(5)):
    score = freq_list[i]
    ax.annotate(str(score), (i, 0 + 0.2))



# Turns off grid on the left Axis.
ax.grid(False)

ax.set_title('')
#ax.set_xlim([0, 1500])
plt.xlabel(u'电影流行度', fontproperties=font)
plt.ylabel(u'电影数(部)', fontproperties=font)



fig = plt.gcf()
fig.set_size_inches(12, 8, forward=True)
plt.show()

# %%
"""
Hatching (pattern filled polygons) is supported currently in the PS,
PDF, SVG and Agg backends only.
"""
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Polygon

fig = plt.figure()
ax1 = fig.add_subplot(131)
ax1.bar(range(1, 5), range(1, 5), color='red', edgecolor='black', hatch="/")
ax1.bar(range(1, 5), [6] * 4, bottom=range(1, 5), color='blue', edgecolor='black', hatch='//')
ax1.set_xticks([1.5, 2.5, 3.5, 4.5])

ax2 = fig.add_subplot(132)
bars = ax2.bar(range(1, 5), range(1, 5), color='yellow', ecolor='black') + \
    ax2.bar(range(1, 5), [6] * 4, bottom=range(1, 5), color='green', ecolor='black')
ax2.set_xticks([1.5, 2.5, 3.5, 4.5])

patterns = ('-', '+', 'x', '\\', '*', 'o', 'O', '.')
for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)

ax3 = fig.add_subplot(133)
ax3.fill([1, 3, 3, 1], [1, 1, 2, 2], fill=False, hatch='\\')
ax3.add_patch(Ellipse((4, 1.5), 4, 0.5, fill=False, hatch='*'))
ax3.add_patch(Polygon([[0, 0], [4, 1.1], [6, 2.5], [2, 1.4]], closed=True,
                      fill=False, hatch='/'))
ax3.set_xlim((0, 6))
ax3.set_ylim((0, 2.5))

plt.show()
